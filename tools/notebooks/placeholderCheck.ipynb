// %%
import { DOMParser } from "https://deno.land/x/deno_dom/deno-dom-wasm.ts";

function parsePlainHtml(text) {
  return new DOMParser().parseFromString(text, 'text/html');
}

async function readPlainHtml(url) {
  const resp = await fetch(url);
  if (!resp.ok) return null;
  return parsePlainHtml(await resp.text());
}

async function readPlainHtml(url) {
  const resp = await fetch(url);
  if (!resp.ok) return null;
  return parsePlainHtml(await resp.text());
}

// %%
const urlTemplate = 'https://www.stage.adobe.com/${locale}dc-shared/placeholders.json';
const locales = [
  // EdgeWorker
  '',
  'uk',
  'fr',
  'de',
  'jp',
  'ca',
  'es',
  'it',
  'in',
  'br',
  // Non-EdgeWorker
  'ca_fr',
  'th_th',
  'hk_zh',
  'id_id',
  'au',
  'kr',
  'in_hi',
  'nz',
  'ph_fil',
  'ph_en',
  'my_ms',
  'sg',
  'hk_en',
  'ch_de',
  'eg_en',
  'tw',
  'vn_en',
  'ch_fr',
  'vn_vi',
  'ee',
  'ae_en',
  'ae_ar',
  'be_en',
  'be_nl',
  'be_fr',
  'at',
  'cz',
  'dk',
  'africa',
  'ch_it',
  'eg_ar',
  'bg',
  'gr_en',
  'lu_fr',
  'ng',
  'hu',
  'lu_en',
  'lu_de',
  'mena_ar',
  'il_en',
  'lt',
  'lv',
  'il_he',
  'kw_en',
  'fi',
  'kw_ar',
  'ie',
  'gr_el',
  'mena_en',
  'nl',
  'pt',
  'ar',
  'si',
  'sa_ar',
  'ro',
  'ru',
  'pl',
  'qa_en',
  'ua',
  'no',
  'qa_ar',
  'se',
  'tr',
  'cl',
  'sa_en',
  'sk',
  'za',
  'gt',
  'co',
  'la',
  'pe',
  'ec',
  'cr',
  'pr',
  'mx',
];

const verbs = {
  'pdf-to-jpg': 'pdf-to-image',
  'pdf-to-excel': 'pdf-to-excel',
  'pdf-to-ppt': 'pdf-to-ppt',
  'convert-pdf': 'createpdf',
  'word-to-pdf': 'word-to-pdf',
  'jpg-to-pdf': 'jpg-to-pdf',
  'png-to-pdf': 'png-to-pdf',
  'excel-to-pdf': 'excel-to-pdf',
  'ppt-to-pdf': 'ppt-to-pdf',
  'ocr-pdf': 'ocr-pdf',
  'compress-pdf': 'compress-pdf',
  'pdf-editor': 'add-comment',
  'merge-pdf': 'combine-pdf',
  'split-pdf': 'split-pdf',
  'crop-pdf': 'crop-pages',
  'delete-pdf-pages': 'delete-pages',
  'rotate-pdf': 'rotate-pages',
  'rearrange-pdf': 'reorder-pages',
  'extract-pdf-pages': 'extract-pages',
  'add-pages-to-pdf': 'insert-pdf',
  'add-pdf-page-numbers': 'number-pages',
  'sign-pdf': 'fillsign',
  'request-signature': 'sendforsignature',
  'password-protect-pdf': 'protect-pdf',
  'ai-chat-pdf': 'chat-pdf',
  'study-with-acrobat': 'chat-pdf-student',
};

for (const locale of locales) {
  const url = urlTemplate.replace('${locale}', `${locale}/`);
  const resp = await fetch(url);
  if (!resp.ok) {
    console.log(`${locale} ${verb} not found`);
    continue;
  }
  const json = await resp.json();
  const placeholders = {};
  const dupKeys = [];
  for (const item of json.data) {
    if (item.key in placeholders) {
      dupKeys.push(item.key);
    }
    placeholders[item.key] = item.value;
  }
  if (dupKeys.length > 0) {
    console.log(`Duplicate keys in '${locale}':\n${dupKeys.join('\n')}\n`);
  }

  const verbDescKeyTemplates = [
    'verb-widget-${verb}-description',
    'verb-widget-${verb}-mobile-description',
  ];
  
  for (const verb of Object.keys(verbs)) {
    for (const verbDescKeyTemplate of verbDescKeyTemplates) {
      const verbDescKey = verbDescKeyTemplate.replace('${verb}', verbs[verb]);
      const verbDesc = placeholders[verbDescKey];
      if (!verbDesc) {
        console.log(`${locale} ${verb} ${verbDescKey} not found`);
      }
    }
  }
}
// Out:
// Duplicate keys in '':
// verb-widget-number-pages-description
// verb-widget-number-pages-mobile-description
// verb-widget-combine-pdf-description
// verb-widget-combine-pdf-mobile-description
// Duplicate keys in 'uk':
// verb-widget-cta-demo
// uk pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// fr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// de pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// jp pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ca pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// es pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// Duplicate keys in 'it':
// rnr-title
// rnr-rating-verb
// rnr-rating-noun
// rnr-comments-placeholder
// rnr-comments-label
// rnr-submit-label
// rnr-thank-you-label
// rnr-rating-tooltips
// susi-default-redirect
// acrobat-exit-modal-title
// acrobat-exit-modal-cta-url
// acrobat-exit-modal-cta-label
// SIGN
// ACROBAT
// PDF_PACK
// EXPORT_PDF
// INDIVIDUAL
// TEAM
// BUSINESS
// STUDENTS
// EDU
// CC_ALL_APPS
// FIREFLY
// creative-cloud-pro
// number-gen-credits-cc-pro
// number-gen-credits-cc-enterprise
// number-gen-credits-single-app
// number-gen-credits-ff-standard
// number-gen-credits-ff-pro
// number-gen-credits-ff-premium
// it pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// it pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// in pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// br pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ca_fr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// th_th pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// th_th pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// hk_zh pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// hk_zh pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// id_id pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// au pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// kr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// in_hi pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// nz pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ph_fil pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ph_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// my_ms pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// sg pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// hk_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ch_de pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// eg_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// tw pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// tw pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// vn_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ch_fr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// vn_vi pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// vn_vi pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ee pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ae_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ae_ar pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// ae_ar pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// be_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// be_nl pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// be_fr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// at pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// cz pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// dk pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// africa pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ch_it pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// eg_ar pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// eg_ar pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// bg pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// bg pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// gr_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// lu_fr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ng pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// hu pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// lu_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// lu_de pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// mena_ar pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// mena_ar pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// il_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// Duplicate keys in 'lt':
// rnr-title
// rnr-rating-verb
// rnr-rating-noun
// rnr-comments-placeholder
// rnr-comments-label
// rnr-submit-label
// rnr-thank-you-label
// rnr-rating-tooltips
// susi-default-redirect
// acrobat-exit-modal-title
// acrobat-exit-modal-cta-url
// acrobat-exit-modal-cta-label
// PDF_PACK
// EXPORT_PDF
// CC_ALL_APPS
// creative-cloud-pro
// lt pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// lt pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// lv pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// il_he pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// kw_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// fi pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// kw_ar pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// kw_ar pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ie pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// Duplicate keys in 'gr_el':
// verb-widget-cta
// verb-widget-word-to-pdf-description
// verb-widget-word-to-pdf-mobile-description
// gr_el pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// mena_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// nl pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// pt pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ar pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// si pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// si pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// sa_ar pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// sa_ar pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ro pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ru pdf-to-jpg verb-widget-pdf-to-image-description not found
// ru pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// ru pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ru word-to-pdf verb-widget-word-to-pdf-description not found
// ru word-to-pdf verb-widget-word-to-pdf-mobile-description not found
// pl pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// qa_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ua pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// ua pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// no pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// qa_ar pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// qa_ar pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// se pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// tr pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// tr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// cl pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// sa_en pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// sk pdf-to-jpg verb-widget-pdf-to-image-mobile-description not found
// sk pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// za pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// gt pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// co pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// la pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// pe pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// ec pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// cr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// pr pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
// mx pdf-to-ppt verb-widget-pdf-to-ppt-mobile-description not found
